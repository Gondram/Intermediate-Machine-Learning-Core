# %% [markdown]
# # Feature Engineering Exercise (Core)

# %%
# imports
# for the required section
import pandas as pd
import numpy as np

# for the optional section
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import ConfusionMatrixDisplay, classification_report

pd.set_option('display.max_columns',200)
pd.set_option("display.max_info_rows", 800)
pd.set_option('display.max_info_columns',800)

from sklearn import set_config
set_config(transform_output='pandas')

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("data/bikeshare_train.csv")
df.head(3)
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 0:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 1:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 2:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32

# %%
df = df.drop(columns=['casual','registered'])
df.head(3)
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 0:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 1:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 2:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  count
# 0        81        0.0     16
# 1        80        0.0     40
# 2        80        0.0     32

# %%
df['datetime'] = pd.to_datetime(df['datetime'])
df['datetime'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10886 entries, 0 to 10885
# Series name: datetime
# Non-Null Count  Dtype
# --------------  -----
# 10886 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 85.2 KB

# %%
df['month'] = df['datetime'].dt.month_name()
df['day of week'] = df['datetime'].dt.day_name()
df['hour'] = df['datetime'].dt.hour.astype('object')
df.head(3)
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  count    month day of week hour
# 0        81        0.0     16  January    Saturday    0
# 1        80        0.0     40  January    Saturday    1
# 2        80        0.0     32  January    Saturday    2

# %%
df = df.drop(columns=['datetime','season'])
df.head(3)
# Out:
#    holiday  workingday  weather  temp   atemp  humidity  windspeed  count  \
# 0        0           0        1  9.84  14.395        81        0.0     16
# 1        0           0        1  9.02  13.635        80        0.0     40
# 2        0           0        1  9.02  13.635        80        0.0     32
#
#      month day of week hour
# 0  January    Saturday    0
# 1  January    Saturday    1
# 2  January    Saturday    2

# %%
df['temp'] = df['temp'].apply(lambda x: (x*9/5) + 32)
df['atemp'] = df['atemp'].apply(lambda x: (x*9/5) + 32)
df.head(3)
# Out:
#    holiday  workingday  weather    temp   atemp  humidity  windspeed  count  \
# 0        0           0        1  49.712  57.911        81        0.0     16
# 1        0           0        1  48.236  56.543        80        0.0     40
# 2        0           0        1  48.236  56.543        80        0.0     32
#
#      month day of week hour
# 0  January    Saturday    0
# 1  January    Saturday    1
# 2  January    Saturday    2

# %%
df['temp variance'] = df['temp'] - df['atemp']
df = df.drop(columns='atemp')
df.head(3)
# Out:
#    holiday  workingday  weather    temp  humidity  windspeed  count    month  \
# 0        0           0        1  49.712        81        0.0     16  January
# 1        0           0        1  48.236        80        0.0     40  January
# 2        0           0        1  48.236        80        0.0     32  January
#
#   day of week hour  temp variance
# 0    Saturday    0         -8.199
# 1    Saturday    1         -8.307
# 2    Saturday    2         -8.307

# %% [markdown]
# ### Optional

# %% [markdown]
# #### Functions

# %%
def classification_metrics(y_true, y_pred, label='',
                           output_dict=False, figsize=(8,4),
                           normalize='true', cmap='Blues',
                           colorbar=False):
    # Get the classification report
    report = classification_report(y_true, y_pred)
    ## Print header and report
    header = "-"*70
    print(header, f" Classification Metrics: {label}", header, sep='\n')
    print(report)
    ## CONFUSION MATRICES SUBPLOTS
    fig, axes = plt.subplots(ncols=2, figsize=figsize)
    # create a confusion matrix  of raw counts
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred,
                normalize=None, cmap='gist_gray', colorbar=colorbar,
                ax = axes[0],);
    axes[0].set_title("Raw Counts")
    # create a confusion matrix with the test data
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred,
                normalize=normalize, cmap=cmap, colorbar=colorbar,
                ax = axes[1]);
    axes[1].set_title("Normalized Confusion Matrix")
    # Adjust layout and show figure
    fig.tight_layout()
    plt.show()
    # Return dictionary of classification_report
    if output_dict==True:
        report_dict = classification_report(y_true, y_pred, output_dict=True)
        return report_dict

# %%
def evaluate_classification(model, X_train, y_train, X_test, y_test,
                         figsize=(6,4), normalize='true', output_dict = False,
                            cmap_train='Blues', cmap_test="Reds",colorbar=False):
    # Get predictions for training data
    y_train_pred = model.predict(X_train)
    # Call the helper function to obtain regression metrics for training data
    results_train = classification_metrics(y_train, y_train_pred, #verbose = verbose,
                                     output_dict=True, figsize=figsize,
                                         colorbar=colorbar, cmap=cmap_train,
                                     label='Training Data')
    print()
    # Get predictions for test data
    y_test_pred = model.predict(X_test)
    # Call the helper function to obtain regression metrics for test data
    results_test = classification_metrics(y_test, y_test_pred, #verbose = verbose,
                                  output_dict=True,figsize=figsize,
                                         colorbar=colorbar, cmap=cmap_test,
                                    label='Test Data' )
    if output_dict == True:
        # Store results in a dataframe if ouput_frame is True
        results_dict = {'train':results_train,
                    'test': results_test}
        return results_dict

# %% [markdown]
# #### Models

# %%
og_df = pd.read_csv("data/bikeshare_train.csv").drop(columns=['casual','registered'])
og_df.head(3)
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 0:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 1:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 2:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  count
# 0        81        0.0     16
# 1        80        0.0     40
# 2        80        0.0     32

# %%
# for engineered data
target = 'count'
X = df.drop(columns=target).copy()
y = df[target].copy()
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42)
# for the og data
og_X = og_df.drop(columns=target).copy()
og_y = og_df[target].copy()
og_X_train, og_X_test, og_y_train, og_y_test = train_test_split(og_X,og_y, random_state=42)

# %% [markdown]
# ##### Engineered Data

# %%
# setting the numerical part of a pipeline
num_cols = X_train.select_dtypes('number').columns
scaler = StandardScaler()
num_pipe = make_pipeline(scaler)
num_tuple = ('numeric', num_pipe, num_cols)

# %%
# setting ohe and scalar methods
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
scaler = StandardScaler()

# %%
ohe_cols = X_train.select_dtypes('object').columns
ohe_pipe = make_pipeline(encoder, scaler)
ohe_tuple = ('categorical', ohe_pipe, ohe_cols)

# %%
# setting up preprocessor
preprocessor = ColumnTransformer([num_tuple, ohe_tuple],
                                    verbose_feature_names_out=False, remainder='drop')

# %%
# Make an instance of the model with default parameters
rf = RandomForestClassifier(random_state=42)
rf_pipe = make_pipeline(preprocessor, rf)
rf_pipe.fit(X_train, y_train)

# Evaluate the default model
evaluate_classification(rf_pipe, X_train, y_train, X_test, y_test)
# Out:
# ----------------------------------------------------------------------
#  Classification Metrics: Training Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00
#          837       1.00      1.00      1.00         2
#          839       1.00      1.00      1.00         2
#          843       1.00      1.00      1.00         1
#          844       1.00      1.00      1.00         1
#          846       1.00      1.00      1.00         1
#          848       1.00      1.00      1.00         1
#          850       1.00      1.00      1.00         1
#          851       1.00      1.00      1.00         1
#          852       1.00      1.00      1.00         1
#          854       1.00      1.00      1.00         1
#          856       1.00      1.00      1.00         1
#          857       1.00      1.00      1.00         1
#          858       1.00      1.00      1.00         2
#          862       1.00      1.00      1.00         1
#          863       1.00      1.00      1.00         1
#          865       1.00      1.00      1.00         1
#          867       1.00      1.00      1.00         1
#          868       1.00      1.00      1.00         2
#          869       1.00      1.00      1.00         1
#          873       1.00      1.00      1.00         1
#          884       1.00      1.00      1.00         1
#          886       1.00      1.00      1.00         1
#          887       1.00      1.00      1.00         1
#          891       1.00      1.00      1.00         1
#          892       1.00      1.00      1.00         1
#          897       1.00      1.00      1.00         1
#          900       1.00      1.00      1.00         1
#          901       1.00      1.00      1.00         1
#          917       1.00      1.00      1.00         1
#          943       1.00      1.00      1.00         1
#          968       1.00      1.00      1.00         1
#          970       1.00      1.00      1.00         1
#
#     accuracy                           1.00      8164
#    macro avg       1.00      1.00      1.00      8164
# weighted avg       1.00      1.00      1.00      8164
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 7
#       4 rf_pipe.fit(X_train, y_train)
#       6 # Evaluate the default model
# ----> 7 evaluate_classification(rf_pipe, X_train, y_train, X_test, y_test)
#
# Cell In[10], line 7, in evaluate_classification(model, X_train, y_train, X_test, y_test, figsize, normalize, output_dict, cmap_train, cmap_test, colorbar)
#       5 y_train_pred = model.predict(X_train)
#       6 # Call the helper function to obtain regression metrics for training data
# ----> 7 results_train = classification_metrics(y_train, y_train_pred, #verbose = verbose,
#       8                                  output_dict=True, figsize=figsize,
#       9                                      colorbar=colorbar, cmap=cmap_train,
#      10                                  label='Training Data')
#      11 print()
#      12 # Get predictions for test data
#
# Cell In[9], line 25, in classification_metrics(y_true, y_pred, label, output_dict, figsize, normalize, cmap, colorbar)
#      23 # Adjust layout and show figure
#      24 fig.tight_layout()
# ---> 25 plt.show()
#      26 # Return dictionary of classification_report
#      27 if output_dict==True:
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\matplotlib\pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\IPython\core\formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\IPython\core\formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\matplotlib\backend_bases.py:2346, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
# -> 2346         bbox_inches = self.figure.get_tightbbox(
#    2347             renderer, bbox_extra_artists=bbox_extra_artists)
#    2348         if pad_inches is None:
#    2349             pad_inches = rcParams['savefig.pad_inches']
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\matplotlib\figure.py:1753, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1749 if ax.get_visible():
#    1750     # some axes don't take the bbox_extra_artists kwarg so we
#    1751     # need this conditional....
#    1752     try:
# -> 1753         bbox = ax.get_tightbbox(
#    1754             renderer, bbox_extra_artists=bbox_extra_artists)
#    1755     except TypeError:
#    1756         bbox = ax.get_tightbbox(renderer)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\matplotlib\axes\_base.py:4408, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4405     bbox_artists = self.get_default_bbox_extra_artists()
#    4407 for a in bbox_artists:
# -> 4408     bbox = a.get_tightbbox(renderer)
#    4409     if (bbox is not None
#    4410             and 0 < bbox.width < np.inf
#    4411             and 0 < bbox.height < np.inf):
#    4412         bb.append(bbox)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\matplotlib\artist.py:367, in Artist.get_tightbbox(self, renderer)
#     352 def get_tightbbox(self, renderer=None):
#     353     """
#     354     Like `.Artist.get_window_extent`, but includes any clipping.
#     355
#    (...)
#     365         The enclosing bounding box (in figure pixel coordinates).
#     366     """
# --> 367     bbox = self.get_window_extent(renderer)
#     368     if self.get_clip_on():
#     369         clip_box = self.get_clip_box()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\matplotlib\text.py:961, in Text.get_window_extent(self, renderer, dpi)
#     959 bbox, info, descent = self._get_layout(self._renderer)
#     960 x, y = self.get_unitless_position()
# --> 961 x, y = self.get_transform().transform((x, y))
#     962 bbox = bbox.translated(x, y)
#     963 return bbox
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\matplotlib\transforms.py:1490, in Transform.transform(self, values)
#    1487 values = values.reshape((-1, self.input_dims))
#    1489 # Transform the values
# -> 1490 res = self.transform_affine(self.transform_non_affine(values))
#    1492 # Convert the result back to the shape of the input values.
#    1493 if ndim == 0:
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\matplotlib\transforms.py:2415, in CompositeGenericTransform.transform_affine(self, points)
#    2413 def transform_affine(self, points):
#    2414     # docstring inherited
# -> 2415     return self.get_affine().transform(points)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\matplotlib\transforms.py:2441, in CompositeGenericTransform.get_affine(self)
#    2439     return self._b.get_affine()
#    2440 else:
# -> 2441     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2442                            self._a.get_affine().get_matrix()))
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\matplotlib\transforms.py:1895, in Affine2D.__init__(self, matrix, **kwargs)
#    1892 if matrix is None:
#    1893     # A bit faster than np.identity(3).
#    1894     matrix = IdentityTransform._mtx
# -> 1895 self._mtx = matrix.copy()
#    1896 self._invalid = 0
#
# KeyboardInterrupt:

# %% [markdown]
# ##### OG Data

# %%
# setting the numerical part of a pipeline
og_num_cols = og_X_train.select_dtypes('number').columns
scaler = StandardScaler()
og_num_pipe = make_pipeline(scaler)
og_num_tuple = ('numeric', og_num_pipe, og_num_cols)

# %%
og_ohe_cols = og_X_train.select_dtypes('object').columns
og_ohe_pipe = make_pipeline(encoder, scaler)
og_ohe_tuple = ('categorical', og_ohe_pipe, og_ohe_cols)

# %%
# setting up preprocessor
og_preprocessor = ColumnTransformer([og_num_tuple, og_ohe_tuple],
                                    verbose_feature_names_out=False, remainder='drop')

# %%
# Make an instance of the model with default parameters
og_rf = RandomForestClassifier(random_state=42)
og_rf_pipe = make_pipeline(og_preprocessor, og_rf)
og_rf_pipe.fit(og_X_train, og_y_train)

# Evaluate the default model
evaluate_classification(og_rf_pipe, og_X_train, og_y_train, og_X_test, og_y_test)

# %% [markdown]
# **Did these feature engineering choices improve your ability to predict the 'count'?**
# - Answer
